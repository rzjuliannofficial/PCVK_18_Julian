# %% [markdown]
# <a href="https://colab.research.google.com/github/rzjuliannofficial/PCVK_18_Julian/blob/main/P1_TugasD2_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LINK [GCOLAB](https://colab.research.google.com/drive/13SbtVElLiw4h4CVU1rY8ktyACI8MgS-z?usp=sharing)**

# %% [markdown]
# # Langkah (Step) 1:
#
# Pada code awal, beberapa library yang akan digunakan adalah: numpy, pandas, cv2, skimage, PIL, matplotlib
# **--Bahasa--**
#
# **--English--**
#
# ***Numpy*** is an array manipulation library, used for linear algebra, Fourier transform, and random number capabilities.
#
# ***Pandas*** is a library for data manipulation and data analysis.
#
# ***CV2*** is a library for computer vision tasks.
#
# ***Skimage*** is a library which supports image processing applications on python.
#
# ***Matplotlib*** is a library which generates figures and provides graphical user interface toolkit.

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# # Langkah (Step) 2:
#
# Baca Image dari URLs - Read Image From URLs
#
# --Bahasa--
# Pada Langkah ini kita akan membaca image dari URLs, menampilkannya menggunakan OpenCV, perhatikan ada perbedaan ketika membuk image dalam RGB dan BGR. Channel Warna default untuk OpenCV adalah BGR.
#
# --English--
# In this step we will read images from urls, and display them using openCV, please note the difference when reading image in RGB and BGR format. The default input color channels are in BGR format for openCV. RGB?

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placecats.com/800/571"]

# Baca dan tampilkan image
# loopp pada tiap url image, bebeerapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                           #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)  #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)   #convert image to RGB
  final_frame = cv.hconcat((image, image_2))       #concat image
  cv2_imshow(final_frame)                          #display image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # Step 3
#
# Melihat ukuran file Image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# # Langkah (Step) 4
# mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # PERTANYAAN PRAKTIKUM D2
#
# **1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?**
#
#
# - Kita menggunakan Google Colab karena Google Colab sudah menyediakan akses GPU dan TPU gratis dan integrasinya dengan Google Drive untuk penyimpanan, pustaka mutakhir seperti TensorFlow, PyTorch, dan OpenCV tanpa
# perlu konfigurasi manual.
#
# **2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?**
#
# - numpy (import numpy as np): Digunakan untuk komputasi numerik dan manipulasi struktur data array multidimensi (ndarray). Pada citra digital, citra direpresentasikan dan dimanipulasi sebagai matriks angka 2D atau 3D melalui array NumPy.
#
# - pandas (import pandas as pd): Library untuk manipulasi dan analisis data tabular (seperti DataFrame). Umumnya digunakan saat bekerja dengan dataset citra beranotasi atau analisis fitur citra dalam bentuk tabel.
# - cv2 (import cv2 as cv): Library OpenCV untuk pengolahan citra dan visi komputer tingkat lanjut. Digunakan untuk operasi transformasi, pembacaan, resizing, konversi ruang warna (color space), hingga deteksi objek.  google.colab.patches.
# - cv2_imshow: Patch khusus untuk Google Colab. Fungsi asli cv2.imshow() dari OpenCV menyebabkan crash pada lingkungan server/cloud Colab, sehingga fungsi ini digunakan sebagai pengganti untuk menampilkan citra langsung di dalam notebook.
# - skimage (from skimage import io, transform): Library Scikit-Image untuk pemrosesan citra digital ilmiah. Modul io digunakan untuk membaca/menyimpan citra (khususnya membaca langsung dari URL web) dan modul transform untuk operasi geometris citra.
# - PIL (from PIL import Image):
# Python Imaging Library (Pillow) yang menyediakan format representasi citra dasar, pembacaan, manipulasi dasar, dan konversi format file citra.
# - matplotlib.pylab / matplotlib.pyplot (import matplotlib.pylab as plt): Library untuk visualisasi data dan grafik. Digunakan untuk mem-plot citra ke dalam canvas koordinat (sumbu $X$ dan $Y$) serta menampilkan perbandingan beberapa citra (subplot).
#
# - Tidak HARUS /WAJIB, Library seperti pandas, LIB dan PIL belum digunakan di D2 langkah 1-4.
#
# **3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?**
#
#
# - untuk memperkecil atau desize ukuran gambar menjadi 0.5 gambar asli. Jika tidak dilakukan maka gambar terlalu besar di Colab dan dapat memperlambat sistem karena lebih berat dan besar
#
#
# -4. Perhatikan potongan kode progam berikut:
# ######membuat garis horizontal ditengah image
#     for y in range (lebar):
#     image_3[int((tinggi)/2),y] = [255,255,255]
# Apakah kegunaan kode [255,255,255]? Jelaskan!**
#
# - Kegunaannya untuk memberikan warna putih di  RGB.
#
#
# **5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!**
#
# - Jika suatu gambar memiliki resolusi tinggi maka pixelnya banyak dan rapat. Sedangkan jika resolusi gambar  tersebeut rendah, maka otomatis pixelnya lebih  sedikit yang akan mengakibatkan gambar kurang jelas dan pixel gambar terlihat jelas.

# %% [markdown]
# #TUGAS PRAKTIKUM D2
#
# 1. Buat garis vertikal dan garis menyilang diagonal pada image keluaran
# 2. Buat garis horisontal berwarna putih dibagian tengah gambar dengan
# panjang tertentu
# 3. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %%
#1 Garis Vertikal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi) :
  image_5[x,int((lebar)/2)] = [255,255,255]

final_frame_1 = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame_1)

# Garis Diagonal
image_6 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
for x in range(tinggi) :
  image_6[x, int(x * (lebar / tinggi))] = [255, 255, 255]

  # Diagonal 2 (kanan atas ke kiri bawah)
  image_6[x, int((tinggi - 1 - x) * (lebar / tinggi))] = [255, 255, 255]

final_frame_2 = cv.hconcat((image_2, image_6))
cv2_imshow(final_frame_2)

#2 Garis ditengah dengan panjang tertentu
image_7 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
y_awal = int((lebar)/2 - 100)
y_akhir = int((lebar)/2 + 50)
for y in range (y_awal, y_akhir):
  image_7[int((tinggi)/2),y] = [255,255,255]

final_frame_3 = cv.hconcat((image_2, image_7))
cv2_imshow(final_frame_3)

#3 Kumpulan pixel disembarang tempat
image_kotak = image_2.copy()

for b in range(80, 160):       # Loop baris (tinggi)
  for k in range(120, 200):    # Loop kolom (lebar)
    image_kotak[b, k] = [255, 255, 255]

final_frame_4 = cv.hconcat((image_2, image_kotak))
cv2_imshow(final_frame_4)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>
